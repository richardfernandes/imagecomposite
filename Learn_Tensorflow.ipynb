# %%
import os

os.environ["KERAS_BACKEND"] = "tensorflow"

import tensorflow as tf
import pandas as pd
import keras
from keras.utils import FeatureSpace

# %%
file_url = "http://storage.googleapis.com/download.tensorflow.org/data/heart.csv"
dataframe = pd.read_csv(file_url)

print(dataframe.shape)
# Out:
# (303, 14)

# %%
dataframe.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   1       145   233    1        2      150      0      2.3      3
# 1   67    1   4       160   286    0        2      108      1      1.5      2
# 2   67    1   4       120   229    0        2      129      1      2.6      2
# 3   37    1   3       130   250    0        0      187      0      3.5      3
# 4   41    0   2       130   204    0        2      172      0      1.4      1
#
#    ca        thal  target
# 0   0       fixed       0
# 1   3      normal       1
# 2   2  reversible       0
# 3   0      normal       0
# 4   0      normal       0

# %%
val_dataframe = dataframe.sample(frac=0.2, random_state=1337)
train_dataframe = dataframe.drop(val_dataframe.index)

print(
    "Using %d samples for training and %d for validation"
    % (len(train_dataframe), len(val_dataframe))
)
# Out:
# Using 242 samples for training and 61 for validation

# %%
def dataframe_to_dataset(dataframe):
    dataframe = dataframe.copy()
    labels = dataframe.pop("target")
    ds = tf.data.Dataset.from_tensor_slices((dict(dataframe), labels))
    ds = ds.shuffle(buffer_size=len(dataframe))
    return ds


train_ds = dataframe_to_dataset(train_dataframe)
val_ds = dataframe_to_dataset(val_dataframe)

# %%
for x, y in train_ds.take(1):
    print("Input:", x)
    print("Target:", y)
# Out:
# Input: {'age': <tf.Tensor: shape=(), dtype=int64, numpy=61>, 'sex': <tf.Tensor: shape=(), dtype=int64, numpy=1>, 'cp': <tf.Tensor: shape=(), dtype=int64, numpy=4>, 'trestbps': <tf.Tensor: shape=(), dtype=int64, numpy=138>, 'chol': <tf.Tensor: shape=(), dtype=int64, numpy=166>, 'fbs': <tf.Tensor: shape=(), dtype=int64, numpy=0>, 'restecg': <tf.Tensor: shape=(), dtype=int64, numpy=2>, 'thalach': <tf.Tensor: shape=(), dtype=int64, numpy=125>, 'exang': <tf.Tensor: shape=(), dtype=int64, numpy=1>, 'oldpeak': <tf.Tensor: shape=(), dtype=float64, numpy=3.6>, 'slope': <tf.Tensor: shape=(), dtype=int64, numpy=2>, 'ca': <tf.Tensor: shape=(), dtype=int64, numpy=1>, 'thal': <tf.Tensor: shape=(), dtype=string, numpy=b'normal'>}
# Target: tf.Tensor(1, shape=(), dtype=int64)

# %%
train_ds = train_ds.batch(32)
val_ds = val_ds.batch(32)

# %%
feature_space = FeatureSpace(
    features={
        # Categorical features encoded as integers
        "sex": "integer_categorical",
        "cp": "integer_categorical",
        "fbs": "integer_categorical",
        "restecg": "integer_categorical",
        "exang": "integer_categorical",
        "ca": "integer_categorical",
        # Categorical feature encoded as string
        "thal": "string_categorical",
        # Numerical features to discretize
        "age": "float_discretized",
        # Numerical features to normalize
        "trestbps": "float_normalized",
        "chol": "float_normalized",
        "thalach": "float_normalized",
        "oldpeak": "float_normalized",
        "slope": "float_normalized",
    },
    # We create additional features by hashing
    # value co-occurrences for the
    # following groups of categorical features.
    crosses=[("sex", "age"), ("thal", "ca")],
    # The hashing space for these co-occurrences
    # wil be 32-dimensional.
    crossing_dim=32,
    # Our utility will one-hot encode all categorical
    # features and concat all features into a single
    # vector (one vector per sample).
    output_mode="concat",
)

# %%
feature_space = FeatureSpace(
    features={
        # Categorical features encoded as integers
        "sex": FeatureSpace.integer_categorical(num_oov_indices=0),
        "cp": FeatureSpace.integer_categorical(num_oov_indices=0),
        "fbs": FeatureSpace.integer_categorical(num_oov_indices=0),
        "restecg": FeatureSpace.integer_categorical(num_oov_indices=0),
        "exang": FeatureSpace.integer_categorical(num_oov_indices=0),
        "ca": FeatureSpace.integer_categorical(num_oov_indices=0),
        # Categorical feature encoded as string
        "thal": FeatureSpace.string_categorical(num_oov_indices=0),
        # Numerical features to discretize
        "age": FeatureSpace.float_discretized(num_bins=30),
        # Numerical features to normalize
        "trestbps": FeatureSpace.float_normalized(),
        "chol": FeatureSpace.float_normalized(),
        "thalach": FeatureSpace.float_normalized(),
        "oldpeak": FeatureSpace.float_normalized(),
        "slope": FeatureSpace.float_normalized(),
    },
    # Specify feature cross with a custom crossing dim.
    crosses=[
        FeatureSpace.cross(feature_names=("sex", "age"), crossing_dim=64),
        FeatureSpace.cross(
            feature_names=("thal", "ca"),
            crossing_dim=16,
        ),
    ],
    output_mode="concat",
)

# %%
train_ds_with_no_labels = train_ds.map(lambda x, _: x)
feature_space.adapt(train_ds_with_no_labels)

for x, _ in train_ds.take(1):
    preprocessed_x = feature_space(x)
    print("preprocessed_x.shape:", preprocessed_x.shape)
    print("preprocessed_x.dtype:", preprocessed_x.dtype)
# Out:
# WARNING:tensorflow:From C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\keras\src\backend\tensorflow\core.py:192: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# preprocessed_x.shape: (32, 138)
# preprocessed_x.dtype: <dtype: 'float32'>

# %%
preprocessed_train_ds = train_ds.map(
    lambda x, y: (feature_space(x), y), num_parallel_calls=tf.data.AUTOTUNE
)
preprocessed_train_ds = preprocessed_train_ds.prefetch(tf.data.AUTOTUNE)

preprocessed_val_ds = val_ds.map(
    lambda x, y: (feature_space(x), y), num_parallel_calls=tf.data.AUTOTUNE
)
preprocessed_val_ds = preprocessed_val_ds.prefetch(tf.data.AUTOTUNE)

# %%
dict_inputs = feature_space.get_inputs()
encoded_features = feature_space.get_encoded_features()

x = keras.layers.Dense(32, activation="relu")(encoded_features)
x = keras.layers.Dropout(0.5)(x)
predictions = keras.layers.Dense(1, activation="sigmoid")(x)

training_model = keras.Model(inputs=encoded_features, outputs=predictions)
training_model.compile(
    optimizer="adam", loss="binary_crossentropy", metrics=["accuracy"]
)

inference_model = keras.Model(inputs=dict_inputs, outputs=predictions)

# %%
training_model.fit(
    preprocessed_train_ds,
    epochs=50,
    validation_data=preprocessed_val_ds,
    verbose=2,
)
# Out:
# Epoch 1/50
# 8/8 - 0s - 41ms/step - accuracy: 0.8843 - loss: 0.3047 - val_accuracy: 0.8033 - val_loss: 0.3738
# Epoch 2/50
# 8/8 - 0s - 41ms/step - accuracy: 0.8967 - loss: 0.2845 - val_accuracy: 0.8033 - val_loss: 0.3744
# Epoch 3/50
# 8/8 - 0s - 41ms/step - accuracy: 0.8926 - loss: 0.2691 - val_accuracy: 0.8033 - val_loss: 0.3753
# Epoch 4/50
# 8/8 - 0s - 40ms/step - accuracy: 0.8802 - loss: 0.2937 - val_accuracy: 0.8197 - val_loss: 0.3770
# Epoch 5/50
# 8/8 - 0s - 44ms/step - accuracy: 0.8802 - loss: 0.2901 - val_accuracy: 0.8033 - val_loss: 0.3778
# Epoch 6/50
# 8/8 - 0s - 43ms/step - accuracy: 0.8719 - loss: 0.2729 - val_accuracy: 0.8197 - val_loss: 0.3790
# Epoch 7/50
# 8/8 - 0s - 41ms/step - accuracy: 0.8884 - loss: 0.2613 - val_accuracy: 0.8197 - val_loss: 0.3799
# Epoch 8/50
# 8/8 - 0s - 40ms/step - accuracy: 0.9091 - loss: 0.2466 - val_accuracy: 0.8197 - val_loss: 0.3826
# Epoch 9/50
# 8/8 - 0s - 40ms/step - accuracy: 0.8760 - loss: 0.2672 - val_accuracy: 0.8197 - val_loss: 0.3855
# Epoch 10/50
# 8/8 - 0s - 42ms/step - accuracy: 0.9174 - loss: 0.2516 - val_accuracy: 0.8197 - val_loss: 0.3869
# Epoch 11/50
# 8/8 - 0s - 40ms/step - accuracy: 0.8926 - loss: 0.2494 - val_accuracy: 0.8197 - val_loss: 0.3874
# Epoch 12/50
# 8/8 - 0s - 40ms/step - accuracy: 0.9050 - loss: 0.2563 - val_accuracy: 0.8197 - val_loss: 0.3884
# Epoch 13/50
# 8/8 - 0s - 43ms/step - accuracy: 0.8967 - loss: 0.2400 - val_accuracy: 0.8197 - val_loss: 0.3886
# Epoch 14/50
# 8/8 - 0s - 40ms/step - accuracy: 0.9008 - loss: 0.2542 - val_accuracy: 0.8197 - val_loss: 0.3911
# Epoch 15/50
# 8/8 - 0s - 40ms/step - accuracy: 0.8843 - loss: 0.2494 - val_accuracy: 0.8197 - val_loss: 0.3931
# Epoch 16/50
# 8/8 - 0s - 40ms/step - accuracy: 0.9132 - loss: 0.2268 - val_accuracy: 0.8197 - val_loss: 0.3940
# Epoch 17/50
# 8/8 - 0s - 44ms/step - accuracy: 0.9215 - loss: 0.2240 - val_accuracy: 0.8197 - val_loss: 0.3967
# Epoch 18/50
# 8/8 - 0s - 40ms/step - accuracy: 0.8678 - loss: 0.2561 - val_accuracy: 0.8197 - val_loss: 0.3983
# Epoch 19/50
# 8/8 - 0s - 40ms/step - accuracy: 0.8926 - loss: 0.2392 - val_accuracy: 0.8197 - val_loss: 0.3999
# Epoch 20/50
# 8/8 - 0s - 41ms/step - accuracy: 0.9091 - loss: 0.2250 - val_accuracy: 0.8197 - val_loss: 0.4007
# Epoch 21/50
# 8/8 - 0s - 40ms/step - accuracy: 0.9091 - loss: 0.2194 - val_accuracy: 0.8033 - val_loss: 0.4017
# Epoch 22/50
# 8/8 - 0s - 40ms/step - accuracy: 0.9091 - loss: 0.2306 - val_accuracy: 0.8033 - val_loss: 0.4033
# Epoch 23/50
# 8/8 - 0s - 40ms/step - accuracy: 0.9091 - loss: 0.2426 - val_accuracy: 0.8033 - val_loss: 0.4040
# Epoch 24/50
# 8/8 - 0s - 41ms/step - accuracy: 0.9050 - loss: 0.2243 - val_accuracy: 0.8033 - val_loss: 0.4047
# Epoch 25/50
# 8/8 - 0s - 43ms/step - accuracy: 0.9132 - loss: 0.2253 - val_accuracy: 0.8197 - val_loss: 0.4045
# Epoch 26/50
# 8/8 - 0s - 43ms/step - accuracy: 0.9215 - loss: 0.2032 - val_accuracy: 0.8197 - val_loss: 0.4070
# Epoch 27/50
# 8/8 - 0s - 44ms/step - accuracy: 0.9256 - loss: 0.2141 - val_accuracy: 0.8197 - val_loss: 0.4079
# Epoch 28/50
# 8/8 - 0s - 40ms/step - accuracy: 0.9215 - loss: 0.2158 - val_accuracy: 0.8197 - val_loss: 0.4096
# Epoch 29/50
# 8/8 - 0s - 40ms/step - accuracy: 0.9174 - loss: 0.2049 - val_accuracy: 0.8033 - val_loss: 0.4103
# Epoch 30/50
# 8/8 - 0s - 40ms/step - accuracy: 0.9132 - loss: 0.2109 - val_accuracy: 0.8033 - val_loss: 0.4116
# Epoch 31/50
# 8/8 - 0s - 40ms/step - accuracy: 0.9256 - loss: 0.1990 - val_accuracy: 0.8033 - val_loss: 0.4140
# Epoch 32/50
# 8/8 - 0s - 41ms/step - accuracy: 0.9256 - loss: 0.1944 - val_accuracy: 0.8033 - val_loss: 0.4168
# Epoch 33/50
# 8/8 - 0s - 40ms/step - accuracy: 0.9298 - loss: 0.1929 - val_accuracy: 0.8033 - val_loss: 0.4182
# Epoch 34/50
# 8/8 - 0s - 41ms/step - accuracy: 0.9215 - loss: 0.2021 - val_accuracy: 0.8033 - val_loss: 0.4190
# Epoch 35/50
# 8/8 - 0s - 40ms/step - accuracy: 0.9339 - loss: 0.1866 - val_accuracy: 0.8033 - val_loss: 0.4205
# Epoch 36/50
# 8/8 - 0s - 42ms/step - accuracy: 0.9215 - loss: 0.1954 - val_accuracy: 0.8033 - val_loss: 0.4221
# Epoch 37/50
# 8/8 - 0s - 41ms/step - accuracy: 0.9008 - loss: 0.1960 - val_accuracy: 0.8033 - val_loss: 0.4246
# Epoch 38/50
# 8/8 - 0s - 39ms/step - accuracy: 0.9339 - loss: 0.1967 - val_accuracy: 0.8033 - val_loss: 0.4249
# Epoch 39/50
# 8/8 - 0s - 42ms/step - accuracy: 0.9298 - loss: 0.1791 - val_accuracy: 0.8033 - val_loss: 0.4252
# Epoch 40/50
# 8/8 - 0s - 40ms/step - accuracy: 0.9380 - loss: 0.1822 - val_accuracy: 0.8033 - val_loss: 0.4256
# Epoch 41/50
# 8/8 - 0s - 39ms/step - accuracy: 0.9463 - loss: 0.1622 - val_accuracy: 0.8033 - val_loss: 0.4275
# Epoch 42/50
# 8/8 - 0s - 40ms/step - accuracy: 0.9421 - loss: 0.1721 - val_accuracy: 0.8033 - val_loss: 0.4294
# Epoch 43/50
# 8/8 - 0s - 42ms/step - accuracy: 0.9339 - loss: 0.1674 - val_accuracy: 0.8033 - val_loss: 0.4298
# Epoch 44/50
# 8/8 - 0s - 44ms/step - accuracy: 0.8967 - loss: 0.1998 - val_accuracy: 0.8033 - val_loss: 0.4304
# Epoch 45/50
# 8/8 - 0s - 40ms/step - accuracy: 0.9380 - loss: 0.1837 - val_accuracy: 0.8033 - val_loss: 0.4309
# Epoch 46/50
# 8/8 - 0s - 41ms/step - accuracy: 0.9587 - loss: 0.1542 - val_accuracy: 0.8033 - val_loss: 0.4333
# Epoch 47/50
# 8/8 - 0s - 40ms/step - accuracy: 0.9339 - loss: 0.1596 - val_accuracy: 0.8033 - val_loss: 0.4369
# Epoch 48/50
# 8/8 - 0s - 43ms/step - accuracy: 0.9339 - loss: 0.1694 - val_accuracy: 0.7869 - val_loss: 0.4404
# Epoch 49/50
# 8/8 - 0s - 41ms/step - accuracy: 0.9463 - loss: 0.1590 - val_accuracy: 0.8033 - val_loss: 0.4423
# Epoch 50/50
# 8/8 - 0s - 40ms/step - accuracy: 0.9545 - loss: 0.1516 - val_accuracy: 0.8033 - val_loss: 0.4450

# %%
sample = {
    "age": 60,
    "sex": 1,
    "cp": 1,
    "trestbps": 145,
    "chol": 233,
    "fbs": 1,
    "restecg": 2,
    "thalach": 150,
    "exang": 0,
    "oldpeak": 2.3,
    "slope": 3,
    "ca": 0,
    "thal": "fixed",
}

input_dict = {name: tf.convert_to_tensor([value]) for name, value in sample.items()}
predictions = inference_model.predict(input_dict)

print(
    f"This particular patient had a {100 * predictions[0][0]:.2f}% probability "
    "of having a heart disease, as evaluated by our model."
)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# This particular patient had a 16.95% probability of having a heart disease, as evaluated by our model.
